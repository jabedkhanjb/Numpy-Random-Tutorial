# %% [markdown]
# # Seaborn

# %% [markdown]
# #### @jabedkhanjb

# %% [markdown]
# # Visualize Distributions With Seaborn
#
# Seaborn is a library that uses Matplotlib underneath to plot graphs. It will be used to visualize random distributions.

# %% [markdown]
# <i><b>need to install seaborn and matplotlib</b></i>

# %% [markdown]
# <i>Command</i>

# %% [markdown]
# <i><b>pip install seaborn</b></i>
#
# <i><b>pip install matplotlib</b></i>

# %% [markdown]
# # Distplots
#
# Distplot stands for distribution plot, it takes as input an array and plots a curve corresponding to the distribution of points in the array.

# %% [markdown]
# # Import Matplotlib
# Import the pyplot object of the Matplotlib module in your code using the following statement:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Plotting a Distplot

# %% [markdown]
# # import matplotlib.pyplot as plt
# import seaborn as sns
#
# sns.distplot([0, 1, 2, 3, 4, 5])
#
# plt.show()

# %% [markdown]
# # Plotting a Distplot Without the Histogram

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([0, 1, 2, 3, 4, 5], hist=False)

plt.show()
# Out:
# D:\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# <b>Note:</b> We will be using: <b>sns.distplot(arr, hist=False)</b> to visualize random distributions in this tutorial.
